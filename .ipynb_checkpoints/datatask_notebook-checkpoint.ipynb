# %% [markdown]
# # Datatask assignment:
#
# Purchase orders given to us by organizations are often dirty. Right now we have very manual ways of cleaning up this data and matching it to products within our database. This small project is one potential solution to this problem.
#
# Project - Python text similarity clustering
#
# Research metrics for determining similarities between two strings.
# Research methods of clustering that would work well with text-based data.
# Write a script that parses through the data file and clusters the text into distinct groups.
# The clusters should ideally be of different products with some margin of error, for example consider fuzzy clustering or LDA.
# Visualize your results
#
# Please work in an ipython notebook using Python 3.

# %% [markdown]
# # My research
# Link: https://docs.google.com/document/d/1DpblLpTK_cfytejuwRMQvFvb35WyW3CcAktD0-N5als/edit?usp=sharing

# %% [markdown]
# # nltk, sklearn
#
# I found the following simple recipe at:
# https://nlpforhackers.io/recipe-text-clustering/
#
# This simple algorithm uses the nltk and sklearn library and executes the following steps:
#
# 1) Remove punctuation
#
# 2) Tokenize
#
# 3) Stem using Porter stemmer
#
# 4) Vectorize the text using tf-idf, and filtering stopwords
#
# 5) Use k-mean to cluster these vectorized texts.

# %%
import string
import collections
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint

# %%
def process_text(text, stem=True):
    """ Remove punctuation, tokenize, and stem. """
    
#     print("===process_text - text:")
#     print(text)
    
    text = text.translate(str.maketrans('','',string.punctuation))
    tokens = word_tokenize(text)
 
    if stem:
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(t) for t in tokens]

#     print("===process_text - tokens:")
#     print(tokens)
    return tokens
 
def cluster_texts(texts, clusters=3):
    """ Transform texts to Tf-Idf coordinates and cluster texts using K-Means """
    vectorizer = TfidfVectorizer(tokenizer=process_text,
                                 stop_words=stopwords.words('english'),
                                 max_df=0.5,
                                 min_df=0.1,
                                 lowercase=True)
 
    tfidf_model = vectorizer.fit_transform(texts)
    km_model = KMeans(n_clusters=clusters)
    km_model.fit(tfidf_model)
 
    clustering = collections.defaultdict(list)
 
    for idx, label in enumerate(km_model.labels_):
        clustering[label].append(idx)
 
    return clustering

if __name__ == "__main__":
    with open('data.txt', 'r') as f:
        orders = f.readlines()
#     print("===main - orders:")
#     print(orders)

    clusters = cluster_texts(orders, 5) # five clusters
    
    #pprint(dict(clusters))
    clusters_d = dict(clusters)
    for key in clusters_d.keys():
        print("===== Cluster %d=====" % key)
        for i in clusters_d[key]:
            print(orders[i])
# Out:
# ===== Cluster 4=====
# Black Twin Tip Sharpie 12/pk
#
# Fine Sharpie, Black
#
# MARKERS SHARPIE X-TRA FIN PK12  [ SANFORD CORP / 35001 ] Sharpie Permanent Marker Black Extra Fine Tip
#
# Marker, Sharpie, Extra Fine, Black [ OfficeMax N235001 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Black [ OfficeMax N235001 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Black [ OfficeMax N235001 ] NEXT DAY
#
# Marker, Sharpie, Extra Fine, Black [OfficeMax N235001] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Black [ OfficeMax N237001 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Black [ OfficeMax N237001 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Black [ OfficeMax N237001 ] NEXT DAY
#
# Marker, Sharpie, Ultra Fine, Black [OfficeMax N237001] IN STOCK
#
# SHARPIE EXTRA FINE BLACK MARKER,12/pk,Resilient tip delivers ink that dries fast,resists water and stays permanently,Marks on foil ,cellophane,glossy paper and labels,glass,photos,metal,plastiorcelain, rubber,vinyl and more; 12/PK
#
# SHARPIE MARKERS BLACK  PK12  [ SANFORD CORP / 30001 ] Sharpie Permanent Marker Black Fine Tip
#
# SHARPIE MARKERS BLACK PK12 Sharpie Permanent Marker  Black  Fine Tip  Leaves a permanent mark on any surface without smearing. Fine writing tip and quick drying ink guarantee clear  identifiabarkings. Supplied in pack of 12.
#
# SHARPIE MARKERS BLACK PK12Sharpie Permanent Marker, Black, Fine Tip
#
# Sharpie - CD/DVD Twin-Tip Permanent Markers - 4 Pack - Black, 4/Pack, Twin Tip, Fine and Ultra-Fine [ OfficeMax ]
#
# Sharpie - CD/DVD Twin-Tip Permanent Markers - 4 Pack, Color Black, Quantity 4/Pack, Style Twin Tip, Tip Fine and Ultra-Fine
#
# Sharpie - Calligraphic Marker Style Calligraphy Pen - Black, Black, Medium, Each [ OfficeMax ]
#
# Sharpie - Calligraphic Marker Style Calligraphy Pen, Barrel Color Black, Ink Color Black, Point Medium, Quantity Each
#
# Sharpie - Calligraphic Marker Style Calligraphy Pen, Barrel Color Black, Ink Color Black, Point Medium, Quantity Each [ Officemax N240001SH ]
#
# Sharpie - Chisel Tip Permanent Markers, 4-Marker Set - Black, Chisel, Permanent, 4/Pack [OfficeMax]
#
# Sharpie - Chisel-Tip Permanent Marker - Black, Chisel
#
# Sharpie - Chisel-Tip Permanent Marker - Black, Chisel , 12
#
# Sharpie - Chisel-Tip Permanent Marker, Color Black, Quantity 12, Tip Chisel
#
# Sharpie - Extra Fine Permanent Markers - Black, 0.5mm
#
# Sharpie - Extra Fine Permanent Markers - Black, 0.5mm [ OfficeMax ]
#
# Sharpie - Extra Fine Permanent Markers - Black, Extra Fine
#
# Sharpie - Extra Fine Permanent Markers, Color Black, Tip 0.5mm
#
# Sharpie - Extra Fine Permanent Markers, Color Black, Tip 0.5mm
#
# Sharpie - Extra Fine Permanent Markers, Color Black, Tip 0.5mm [ OfficeMax ]
#
# Sharpie - Extra Fine Permanent Markers, Color Black, Tip 0.5mm [ Officemax N235001 ]
#
# Sharpie - Fine Tip Permanent Markers, 5-Marker Pack - Black, 5/Pack
#
# Sharpie - Fine Tip Permanent Markers, 5-Marker Pack - Black, 5/Pack [ OfficeMax ]
#
# Sharpie - Fine Tip Permanent Markers, 5-Marker Pack, Color Black, Quantity 5/Pack
#
# Sharpie - Fine Tip Permanent Markers, 5-Marker Pack, Color Black, Quantity 5/Pack [ Officemax N230665PP ]
#
# Sharpie - Grip Marker, Color Black, Quantity 12, Tip Fine
#
# Sharpie - Grip Marker, Color Black, Quantity 12, Tip Fine [OfficeMax]
#
# Sharpie - Grip Pens - Black, Fine, 3/Pack [ OfficeMax ]
#
# Sharpie - Industrial Permanent Markers - Black, Extra Fine
#
# Sharpie - Industrial Permanent Markers - Black, Extra Fine [ OfficeMax ]
#
# Sharpie - Industrial Permanent Markers - Black, Extra Fine [OfficeMax]
#
# Sharpie - Industrial Permanent Markers - Black, Fine
#
# Sharpie - Industrial Permanent Markers - Black, Fine [ OfficeMax ]
#
# Sharpie - Industrial Permanent Markers - Black, Fine [OfficeMax]
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Extra Fine
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Extra Fine [ Officemax N213801 ]
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Extra Fine [OfficeMax]
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Fine
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Fine [ Officemax N213601 ]
#
# Sharpie - Industrial Permanent Markers, Color Black, Tip Fine [OfficeMax]
#
# Sharpie - King Size Marker - Four Marker Pack - Black, Felt, King Size, 4 per pack
#
# Sharpie - King Size Marker - Four Marker Pack, Color Black, Quantity 4 per pack, Style King Size, Tip Felt
#
# Sharpie - King Size Marker - Four Marker Pack, Color Black, Quantity 4 per pack, Style King Size, Tip Felt [OfficeMax]
#
# Sharpie - King Size Permanent Markers, Color Black, Tip King Size
#
# Sharpie - King Size Permanent Markers, Color Black, Tip King Size [ Officemax N215001 ]
#
# Sharpie - Magnum Permanent Markers, Color Black, Tip Broad Chisel
#
# Sharpie - Magnum Permanent Markers, Color Black, Tip Broad Chisel [ Officemax N244001 ]
#
# Sharpie - Peel-Off China Markers, Color Black, Tip Conical [ Officemax N52089 ]
#
# Sharpie - Permanent Ink Pen - 12 Pack, Black - Black, Fine
#
# Sharpie - Permanent Ink Pen - 12 Pack, Black - Black, Fine
#
# Sharpie - Permanent Ink Pen - 12 Pack, Black - Black, Fine [ OfficeMax ]
#
# Sharpie - Permanent Ink Pen - 12 Pack, Black, Ink Color Black, Point Fine
#
# Sharpie - Permanent Ink Pen, Color Black, Quantity 4, Tip Fine [ Officemax N21742661 ]
#
# Sharpie - Permanent Ink Pen, Ink Color Black, Point Medium
#
# Sharpie - Professional Chisel-Tip Permanent Markers - Black, 2 PK
#
# Sharpie - Professional Chisel-Tip Permanent Markers - Black, 2 PK [ OfficeMax ]
#
# Sharpie - Professional Chisel-Tip Permanent Markers - Includes Black and Red, 2 PK [ OfficeMax ]
#
# Sharpie - Professional Chisel-Tip Permanent Markers, Color Black, Quantity 2 PK
#
# Sharpie - Professional Chisel-Tip Permanent Markers, Color Black, Quantity 2 PK [ Officemax N234821PP ]
#
# Sharpie - Professional Permanent Markers - Black, Chisel [ OfficeMax ]
#
# Sharpie - Professional Permanent Markers, Color Black, Tip Chisel
#
# Sharpie - Retractable Fine Point Permanent Markers, Black Sets - Black, Fine, 12/Dozen [OfficeMax]
#
# Sharpie - Retractable Fine Point Permanent Markers, Black Sets, Color Black, Quantity 3/Pack, Tip Fine [ Officemax N274745PP ]
#
# Sharpie - Retractable Fine-Point Permanent Markers, Black Sets - Black, 12/Dozen, Fine [ OfficeMax ]
#
# Sharpie - Retractable Fine-Point Permanent Markers, Black Sets - Black, Fine, 12/Dozen
#
# Sharpie - Retractable Fine-Point Permanent Markers, Black Sets - Black, Fine, 3/Pack
#
# Sharpie - Retractable Fine-Point Permanent Markers, Black Sets, Color Black, Quantity 12/Dozen, Tip Fine
#
# Sharpie - Retractable Fine-Point Permanent Markers, Black Sets, Color Black, Quantity 3/Pack, Tip Fine
#
# Sharpie - Retractable Ultra-Fine Permanent Markers - Black, 12/Pack, Ultra Fine [ OfficeMax ]
#
# Sharpie - Retractable Ultra-Fine Permanent Markers - Black, Ultra Fine, 12/Pack
#
# Sharpie - Retractable Ultra-Fine Permanent Markers, Color Black, Quantity 12/Pack, Tip Ultra Fine
#
# Sharpie - Retractable Ultra-Fine Permanent Markers, Color Black, Quantity 3/Pack, Tip Ultra Fine
#
# Sharpie - Rub-a-Dub Laundry Marker, Color Black, Quantity 2, Tip Fine
#
# Sharpie - Super Permanent Marker - Black, Fine, 6
#
# Sharpie - Super Permanent Marker, Color Black, Quantity 6, Tip Fine
#
# Sharpie - Super Sharpie Permanent Markers - Black, Bold
#
# Sharpie - Super Sharpie Permanent Markers - Black, Bold [ OfficeMax ]
#
# Sharpie - Super Sharpie Permanent Markers, Color Black, Tip Bold
#
# Sharpie - Super Sharpie Permanent Markers, Color Black, Tip Bold [ Officemax N233001 ]
#
# Sharpie - Super Sharpie Permanent Markers, Color Black, Tip Bold [OfficeMax]
#
# Sharpie - Super Twin-Tip Permanent Markers - 3 Pack - Black, 3/Pack, Twin Tip, Fine and Chisel [ OfficeMax ]
#
# Sharpie - Super Twin-Tip Permanent Markers - 3 Pack - Black, Fine and Chisel, Twin Tip, 3/Pack
#
# Sharpie - Super Twin-Tip Permanent Markers - 3 Pack, Color Black, Quantity 3/Pack, Style Twin Tip, Tip Fine and Chisel
#
# Sharpie - Twin Tip Permanent Markers - 4-Pack, Black - Black, 4/Pack, Twin Tip, Fine, Ultra Fine [ OfficeMax ]
#
# Sharpie - Twin Tip Permanent Markers - 4-Pack, Black - Black, Fine, Ultra Fine, Twin Tip, 4/Pack
#
# Sharpie - Twin Tip Permanent Markers - 4-Pack, Black, Color Black, Quantity 4/Pack, Style Twin Tip, Tip Fine, Ultra Fine
#
# Sharpie - Twin Tip Permanent Markers - 4-Pack, Black, Color Black, Quantity 4/Pack, Style Twin Tip, Tip Fine, Ultra Fine [ Officemax N232175PP ]
#
# Sharpie - Twin Tip Permanent Markers - 4-Pack, Black, Color Black, Quantity 4/Pack, Style Twin Tip, Tip Fine, Ultra Fine [OfficeMax]
#
# Sharpie - Twin Tip Permanent Markers, Color Black, Tip Fine/Ultra Fine [ Officemax N232001 ]
#
# Sharpie - Twin-Tip Permanent Markers, Color Black, Tip Fine/Ultra Fine
#
# Sharpie - Ultra Fine Permanent Markers, Color Black, Tip 0.3mm [ Officemax N237001 ]
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack - Black, 5/Pack
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack - Black, 5/Pack [ OfficeMax ]
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack - Black, 5/Pack [OfficeMax]
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack, Color Black, Quantity 5/Pack
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack, Color Black, Quantity 5/Pack [ Officemax N237665PP ]
#
# Sharpie - Ultra Fine Tip Permanent Markers, 5-Marker Pack, Color Black, Quantity 5/Pack [OfficeMax]
#
# Sharpie Marker, Black
#
# Sharpie Marker, With Fine Tip, Color: Black, 12/PK, Super-permanent black ink formulated for laboratory, industrial, and commercial use, Ink resists most chemical washes, steam, and heat up 60degreeC; 1/PK
#
# Sharpie Marker, With Fine Tip, Color: Black, 12/PK, Super-permanent black ink formulated for laboratory, industrial, and commercial use, Ink resists most chemical washes, steam, and heat up 60degreeC; 1/PK
#
# Sharpie Markers, Black, Fine, Qty.: 12/Pk.; 12/PK
#
# Sharpie Permanent Marker, Black, Extra Fine Tip, Leaves a permanent mark on any surface without smearing. Fine writing tip and quick drying ink guarantee clear, identifiable markings. Supplied ack of 12.
#
# ===== Cluster 1=====
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Blue [ OfficeMax N227010 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Blue [ OfficeMax N227010 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Blue [ OfficeMax N227010 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Blue [OfficeMax N227010] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink [ OfficeMax N227009 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink [ OfficeMax N227009 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink [ OfficeMax N227009 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink [OfficeMax N227009] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Yellow [ OfficeMax N227005 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Yellow [ OfficeMax N227005 ] IN STOCK
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Yellow [ OfficeMax N227005 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Pocket-Style Highlighters, Color Yellow [OfficeMax N227005] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Pink, Style Standard [ OfficeMax N225009 ] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Pink, Style Standard [ OfficeMax N225009 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Pink, Style Standard [OfficeMax N225009] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Turquoise Blue, Style Standard [ OfficeMax N225010 ] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Turquoise Blue, Style Standard [ OfficeMax N225010 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Turquoise Blue, Style Standard [OfficeMax N225010] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard [ OfficeMax N225005 ] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard [ OfficeMax N225005 ] IN STOCK
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard [ OfficeMax N225005 ] NEXT DAY
#
# Highlighter, Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard [OfficeMax N225005] IN STOCK
#
# ORDER IN QUANTITIES OF 12. Sharpie Accent - Liquid Pen-Style Highlighters, Color Fluorescent Purple [ Officemax N224408S ]
#
# Sharpie - Accent Gel Highlighters, Color Fluorescent Yellow
#
# Sharpie - Accent Grip Highlighters - 8-Color Set - Fluorescent pink, yellow, orange, blue, berry, indigo, red and green, 8/Set
#
# Sharpie - Accent Liquid Pen-Style Highlighters - Fluorescent Green, Chisel Tip, 12/DZ
#
# Sharpie - Accent Liquid Pen-Style Highlighters - Fluorescent Orange
#
# Sharpie - Accent Liquid Pen-Style Highlighters - Fluorescent Purple, Chisel Tip, 12/DZ
#
# Sharpie - Accent Liquid Pen-Style Highlighters - Fluorescent Yellow
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set - Fluorescent Yellow, 5/Pack
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set - Fluorescent Yellow, 5/Pack [ OfficeMax ]
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set - Fluorescent Yellow,Pink, Orange, Green and Blue, 5/Set
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set - Fluorescent Yellow,Pink, Orange, Green and Blue, 5/Set [ OfficeMax ]
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow, Quantity 5/Pack
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow,Pink, Orange, Green and Blue, Quantity 5/Set
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Blue, Quantity 12/DZ, Style Chisel Tip
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Green, Quantity 12/DZ, Style Chisel Tip
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Orange, Quantity 12/DZ, Style Chisel Tip
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Pink
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Purple, Quantity 12/DZ, Style Chisel Tip
#
# Sharpie - Accent Liquid Pen-Style Highlighters, Color Fluorescent Yellow
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Color Set - Fluorescent Pink, Green and Yellow, 3/Set
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Color Set - Fluorescent Pink, Green and Yellow, 3/Set [ OfficeMax ]
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Color Set, Color Fluorescent Pink, Green and Yellow, Quantity 3/Set
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Pack - Yellow, 3/Pack
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Pack - Yellow, 3/Pack [ OfficeMax ]
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 3-Pack, Color Yellow, Quantity 3/Pack
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 8-Color Set - Assorted, 8/Set
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 8-Color Set - Assorted, 8/Set [ OfficeMax ]
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 8-Color Set - Assorted, 8/Set, Chisel
#
# Sharpie - Accent Pen-Style Retractable Highlighters, 8-Color Set, Color Assorted, Quantity 8/Set
#
# Sharpie - Accent Pink Ribbon Pocket Style Highlighter, Color Pink, Quantity 2, Style Standard
#
# Sharpie - Jumbo Highlighters - Fluorescent Green, Pink, Yellow, Orange, 6/Set [ OfficeMax ]
#
# Sharpie - Jumbo Highlighters, Color Flourescent Green, Pink, Yellow, Orange, Quantity 6/Set [ Officemax N21733165 ]
#
# Sharpie - Jumbo Highlighters, Color Fluorescent Green, Pink, Yellow, Orange, Quantity 6/Set
#
# Sharpie - Jumbo Highlighters, Color Pink, Quantity 12
#
# Sharpie - Jumbo Highlighters, Color Yellow, Quantity 12
#
# Sharpie - Retractable Highlighters, Color Fluorescent Yellow, Quantity 12, Style Standard [ Officemax N228025 ]
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Blue
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Fluorescent Green
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Fluorescent Orange
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Fluorescent Pink
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Fluorescent Yellow
#
# Sharpie Accent - Accent Pocket-Style Highlighters - Yellow
#
# Sharpie Accent - Accent Pocket-Style Highlighters, Color Blue
#
# Sharpie Accent - Accent Pocket-Style Highlighters, Color Fluorescent Pink
#
# Sharpie Accent - Accent Pocket-Style Highlighters, Color Yellow
#
# Sharpie Accent - Grip Highlighters - 8-Color Set - Fluorescent pink, yellow, orange, blue, berry, indigo, red and green, 8/Set
#
# Sharpie Accent - Grip Highlighters - 8-Color Set, Color Assorted, Quantity 8/Set [OfficeMax]
#
# Sharpie Accent - Grip Highlighters - 8-Color Set, Color Fluorescent pink, yellow, orange, blue, berry, indigo, red and green, Quantity 8/Set
#
# Sharpie Accent - Grip Highlighters - 8-Color Set, Color Fluorescent pink, yellow, orange, blue, berry, indigo, red and green, Quantity 8/Set [ Officemax N221975 ]
#
# Sharpie Accent - Grip Highlighters - Fluorescent Yellow, Dozen
#
# Sharpie Accent - Grip Highlighters - Fluorescent Yellow, Dozen [ OfficeMax ]
#
# Sharpie Accent - Grip Highlighters, Color Fluorescent Pink
#
# Sharpie Accent - Grip Highlighters, Color Fluorescent Yellow, Quantity Dozen
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Color Set - Fluorescent Yellow, 5/Pack [OfficeMax]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Color Set - Fluorescent Yellow,Pink, Orange, Green and Blue, 5/Set [OfficeMax]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow, Quantity 5/Pack [ OfficeMax ]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow, Quantity 5/Pack [ Officemax N224527PP ]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow,Pink, Orange, Green and Blue, Quantity 5/Set [ Officemax N224575PP ]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 5-Set, Color Fluorescent Yellow,Pink, Orange, Green and Blue, Quantity 5/Set [OfficeMax]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, Color Fluorescent Green [ Officemax N224426S ]
#
# Sharpie Accent - Liquid Pen-Style Highlighters, Color Fluorescent Orange [ Officemax N224406S ]
#
# Sharpie Accent - Pen Style Retractable Highlighters, 3-Color Set, Color Fluorescent Pink, Green and Yellow, Quantity 3/Set [ Officemax N228173PP ]
#
# Sharpie Accent - Pen Style Retractable Highlighters, 3-Pack - Yellow, 3/Pack [OfficeMax]
#
# Sharpie Accent - Pen Style Retractable Highlighters, 3-Pack, Color Yellow, Quantity 3/Pack [ Officemax N228124PP ]
#
# Sharpie Accent - Pen Style Retractable Highlighters, 8-Color Set, Color Assorted, Quantity 8/Set [OfficeMax]
#
# Sharpie Accent - Pocket-Style Highlighters - 4-Color Set - Assorted: Fluorescent Pink, Blue, Fluorescent Yellow, Fluorescent Orange, 4/Set [ OfficeMax ]
#
# Sharpie Accent - Pocket-Style Highlighters - 4-Color Set, Color Assorted: Fluorescent Pink, Blue, Fluorescent Yellow, Fluorescent Orange, Quantity 4/Set
#
# Sharpie Accent - Pocket-Style Highlighters - 4-Color Set, Color Assorted: Fluorescent Pink, Blue, Fluorescent Yellow, Fluorescent Orange, Quantity 4/Set [ Officemax N227174PP ]
#
# Sharpie Accent - Pocket-Style Highlighters - Color Sets - Assorted Fluorescent: Pink, Blue, Yellow and Orange, 4/Set
#
# Sharpie Accent - Pocket-Style Highlighters - Color Sets - Assorted: 3 Fluorescent Yellow, 2 Blue, 2 Fluorescent Green, 2 Fluorescent Orange, 2 Fluorescent Pink, 1 Lavender, 12
#
# Sharpie Accent - Pocket-Style Highlighters - Color Sets - Assorted: Fluorescent Pink, Blue, Fluorescent Yellow, Fluorescent Orange, 4/Set
#
# Sharpie Accent - Pocket-Style Highlighters - Color Sets, Color Assorted; 3 Fluorescent Yellow, 2 Each: Blue, Fluor. Pink, Fluor. Green, Fluor. Orange,1 Lavender, Quantity 12/Pk
#
# Sharpie Accent - Pocket-Style Highlighters - Fluorescent Green [ OfficeMax ]
#
# Sharpie Accent - Pocket-Style Highlighters - Fluorescent Orange
#
# Sharpie Accent - Pocket-Style Highlighters - Fluorescent Pink [ OfficeMax ]
#
# Sharpie Accent - Pocket-Style Highlighters - Fluorescent Yellow
#
# Sharpie Accent - Pocket-Style Highlighters - Fluorescent Yellow [ OfficeMax ]
#
# Sharpie Accent - Pocket-Style Highlighters - Lavender [ OfficeMax ]
#
# Sharpie Accent - Pocket-Style Highlighters - Yellow
#
# Sharpie Accent - Pocket-Style Highlighters, Color Blue
#
# Sharpie Accent - Pocket-Style Highlighters, Color Blue [ Officemax N227010 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Green
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Green [ Officemax N227026 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Orange
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Orange [ Officemax N227006 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Orange [OfficeMax]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Pink [ Officemax N227009 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Yellow
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Yellow [ Officemax N227025 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Fluorescent Yellow [OfficeMax]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Lavender
#
# Sharpie Accent - Pocket-Style Highlighters, Color Lavender [ Officemax N227019 ]
#
# Sharpie Accent - Pocket-Style Highlighters, Color Yellow
#
# Sharpie Accent - Pocket-Style Highlighters, Color Yellow [ Officemax N227005 ]
#
# Sharpie Accent - Tank-Style Highlighters - Fluorescent Orange, Standard [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters - Fluorescent Yellow, Standard
#
# Sharpie Accent - Tank-Style Highlighters - Fluorescent Yellow, Standard [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters - Lavender, Standard
#
# Sharpie Accent - Tank-Style Highlighters - Lavender, Standard [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters - Pink, Standard
#
# Sharpie Accent - Tank-Style Highlighters - Pink, Tank
#
# Sharpie Accent - Tank-Style Highlighters - Turquoise Blue, Standard
#
# Sharpie Accent - Tank-Style Highlighters - Yellow, Standard [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters, 12-Dozen - Assorted Fluorescent, 12/Dozen
#
# Sharpie Accent - Tank-Style Highlighters, 12-Dozen - Assorted Fluorescent, 12/Dozen [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters, 12-Dozen, Color Assorted Fluorescent, Quantity 12/Dozen
#
# Sharpie Accent - Tank-Style Highlighters, 12-Dozen, Color Assorted Fluorescent, Quantity 12/Dozen [ Officemax N225053 ]
#
# Sharpie Accent - Tank-Style Highlighters, 4-Pack - Fluorescent Yellow, 4/Pack
#
# Sharpie Accent - Tank-Style Highlighters, 4-Pack - Fluorescent Yellow, 4/Pack, Chisel [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters, 4-Pack, Color Fluorescent Yellow, Quantity 4/Pack, Tip Chisel
#
# Sharpie Accent - Tank-Style Highlighters, 4-Pack, Color Fluorescent Yellow, Quantity 4/Pack, Tip Chisel [ Officemax N225164PP ]
#
# Sharpie Accent - Tank-Style Highlighters, 4-Pack, Color Fluorescent Yellow, Quantity 4/Pack, Tip Chisel [OfficeMax]
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set - Assorted, 6/Set [ OfficeMax ]
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set, Color Assorted, 6/Set
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set, Color Assorted, Quantity 6/Set
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set, Color Assorted, Quantity 6/Set
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set, Color Assorted, Quantity 6/Set [ Officemax N225076 ]
#
# Sharpie Accent - Tank-Style Highlighters, 6-Color Set, Color Assorted, Quantity 6/Set [OfficeMax]
#
# Sharpie Accent - Tank-Style Highlighters, Color Fluorescent Green, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Fluorescent Orange, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Fluorescent Orange, Style Standard [ Officemax N225006 ]
#
# Sharpie Accent - Tank-Style Highlighters, Color Fluorescent Yellow, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Fluorescent Yellow, Style Standard [ Officemax N225025 ]
#
# Sharpie Accent - Tank-Style Highlighters, Color Lavender, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Lavender, Style Standard [ Officemax N225019 ]
#
# Sharpie Accent - Tank-Style Highlighters, Color Pink, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Turquoise Blue, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Turquoise Blue, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard
#
# Sharpie Accent - Tank-Style Highlighters, Color Yellow, Style Standard
#
# ===== Cluster 2=====
# MARKER,SUPER,SHARPIE,BK
#
# MARKERS SHARPIE BLUE PK12  [ SANFORD CORP / 30003 ] Sharpie Permanent Marker Blue Fine Tip
#
# MARKERS SHARPIE BLUE PK12Sharpie Permanent Marker, Blue, Fine Tip
#
# MARKERS SHARPIE GREEN PK12  [ SANFORD CORP / 30004 ] Sharpie Permanent Marker Green Fine Tip
#
# MK,SHARPIE,CHSL,BK
#
# MK,SHARPIE,SR,4/PK
#
# Marker Set, Sharpie, 4 Colors
#
# Marker, Sharpie - Flip Chart Marker, 4-Color Set, Color Black, Red, Blue and Green, Quantity 4/Set, Style Nonsqueak, Tip Bullet [ OfficeMax N222474 ] IN STOCK
#
# Marker, Sharpie - Flip Chart Marker, 4-Color Set, Color Black, Red, Blue and Green, Quantity 4/Set, Style Nonsqueak, Tip Bullet [ OfficeMax N222474 ] NEXT DAY
#
# Marker; Permanent; Sharpie  1mm tip; Pen-style; Four-color assortment; Color: Red, Black, Blue, Green; Quick drying; water-resistant ink in eight brilliant colors; Certified nontoxic; 4/ST; 1/PK
#
# Marker; Permanent; Sharpie 1mm tip; Pen-style; Four-color assortment; Color: Red, Black, Blue, Green; Quick drying; water-resistant ink in eight brilliant colors; Certified nontoxic; 4/ST; 1/PK
#
# PEN,SHARPIE,ASST 4/PK
#
# SHARPIE FN ASST 24 COUNT
#
# SHARPIE NEW COL 12PK
#
# SHARPIE PEN GRIP 3CD ASSTD
#
# SHARPIE PEN RT 3CD ASST
#
# SHARPIE STAINLESS STL FN REFL
#
# SHARPIE TWN TIP BLK 4 PK
#
# SHARPIE UF COL 12 PK
#
# SHARPIE ULTRA FN ASST 24CT
#
# SHARPIE X-FN ASRT 5 PK
#
# SHARPIE,STAINLESS,1CD,BK
#
# Sanford - Sharpie Extra Fine Tip Permanent Markers, 4-Color Set, Color Black, Red, Blue, Green, Tip 0.5mm
#
# Sanford - Sharpie Extra Fine Tip Permanent Markers, 4-Color Set, Color Black, Red, Blue, Green, Tip 0.5mm [ Officemax N235074 ]
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 10-Color Set - Assorted, Micro Chisel Tip, 10/Set
#
# Sharpie - Accent Liquid Pen-Style Highlighters, 10-Color Set, Color Assorted, Quantity 10/Set, Size Micro Chisel Tip
#
# Sharpie - CD/DVD Twin-Tip Permanent Markers, 4-Color Set - Black, Blue, Green, Red, Fine and Ultra-Fine, 4/Set
#
# Sharpie - CD/DVD Twin-Tip Permanent Markers, 4-Color Set, Color Black, Blue, Green, Red, Quantity 4/Set, Tip Fine and Ultra-Fine
#
# Sharpie - Chisel Tip Permanent Ink Markers, Color Blue, Tip Chisel
#
# Sharpie - Chisel Tip Permanent Ink Markers, Color Red, Tip Chisel
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set - Assorted, 8/Set, Permanent, Chisel [ OfficeMax ]
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set - Assorted, Chisel, Permanent, 8/Set
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set - Assorted, Chisel, Permanent, 8/Set [OfficeMax]
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set, Color Assorted, Quantity 8/Set, Style Permanent, Tip Chisel
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set, Color Assorted, Quantity 8/Set, Style Permanent, Tip Chisel [ Officemax N238250PP ]
#
# Sharpie - Chisel Tip Permanent Marker, 8-Color Set, Color Assorted, Quantity 8/Set, Style Permanent, Tip Chisel [OfficeMax]
#
# Sharpie - Chisel Tip Permanent Markers, 4-Marker Set - Black, Chisel, Permanent, 4/Pack
#
# Sharpie - Chisel Tip Permanent Markers, 4-Marker Set, Color Black, Quantity 4/Pack, Style Permanent, Tip Chisel
#
# Sharpie - Chisel Tip Permanent Markers, 4-Marker Set, Color Black, Quantity 4/Pack, Style Permanent, Tip Chisel [ Officemax N238264PP ]
#
# Sharpie - Chisel-Tip Permanent Marker - 4-Color Set - Assorted, Chisel, Permanent, 4/Set
#
# Sharpie - Chisel-Tip Permanent Marker - 4-Color Set, Color Assorted, Quantity 4/Set, Style Permanent, Tip Chisel
#
# Sharpie - Counterfeit Detector Markers, Quantity 3/PK, Style Counterfeit Bill Detector
#
# Sharpie - Five-Color Set - Assorted, 5, Standard [ OfficeMax ]
#
# Sharpie - Five-Color Set, Color Assorted, Quantity 5, Size Standard
#
# Sharpie - Flip Chart Marker, 4-Color Set, Color Black, Red, Blue and Green, Quantity 4/Set, Style Nonsqueak, Tip Bullet
#
# Sharpie - Flip Chart Marker, 4-Color Set, Color Black, Red, Blue and Green, Quantity 4/Set, Style Nonsqueak, Tip Bullet [OfficeMax]
#
# Sharpie - Flip Chart Markers - 7 Color Set - Includes 2 black, red, blue, green, orange, brown and purple, 7-color set;
#
# Sharpie - Flip Chart Markers - 7 Color Set, Color Includes 2 black, red, blue, green, orange, brown and purple, Quantity 7-color set;
#
# Sharpie - Flip Chart Markers, 8-Color Set, Color Black, Red, Blue, Green, Yellow, Orange, Brown and Purple, Quantity 8/Set, Style Nonsqueak, Tip Conical [ OfficeMax ]
#
# Sharpie - Flip Chart Markers, 8-Color Set, Color Black, Red, Blue, Green, Yellow, Orange, Brown and Purple, Quantity 8/Set, Style Nonsqueak, Tip Conical [ Officemax N222478 ]
#
# Sharpie - King Size Permanent Markers - Blue, King Size
#
# Sharpie - King Size Permanent Markers, Color Blue, Tip King Size
#
# Sharpie - King Size Permanent Markers, Color Blue, Tip King Size [ Officemax N215003 ]
#
# Sharpie - Magnum Permanent Markers, Color Blue, Tip Broad Chisel
#
# Sharpie - Marker Style Calligraphy Pens - Five Color Set, Ink Color Assorted, Point Medium, Quantity 5 pens
#
# Sharpie - Marker Style Calligraphy Pens - Five Color Set, Ink Color Assorted, Point Medium, Quantity 5 pens [ Officemax N240050SH ]
#
# Sharpie - Metallic Permanent Marker, Color Silver, Quantity 4/Pack, Style Permanent, Tip Fine
#
# Sharpie - Peel-Off China Markers, Color Yellow, Tip Conical [ Officemax N52083 ]
#
# Sharpie - Permanent Ink Pen - Assorted -
#
# Sharpie - Permanent Ink Pen - Assorted - Assorted - Black, Blue, Green, Red, 4/Pack, Fine [ OfficeMax ]
#
# Sharpie - Permanent Ink Pen - Assorted, Color Assorted - Black, Blue, Green, Red, Quantity 4/Pack, Tip Fine
#
# Sharpie - Pink Ribbon Pen-Style Permanent Marker, Color Pink, Quantity 2?PK, Style Pink Ribbon
#
# Sharpie - Pink Ribbon Pen-Style Permanent Marker, Color Pink, Quantity 2?PK, Style Pink Ribbon [ Officemax N21741763 ]
#
# Sharpie - Professional Chisel-Tip Permanent Markers, Color Includes Black and Red, Quantity 2 PK
#
# Sharpie - Retractable Ultra Fine Permanent Markers - 8-Color Set, Color Assorted [ Officemax N21742025 ]
#
# Sharpie - Retractable Ultra Fine Permanent Markers - 8-Color Set, Color Assorted, Tip Fine
#
# Sharpie - Retractable Ultra Fine Tip Permanent Marker, Color Blue, Quantity 1, Style Standard, Tip Ultra Fine
#
# Sharpie - Retractable Ultra-Fine Permanent Markers, Color Black, Red, Blue, Quantity 3/Pack, Tip Ultra Fine
#
# Sharpie - Sharpie Grip Marker, Color Berry, black, blue, green, lime, range, red and turquoise., Quantity 8 color set, Style Regular, Tip Fine
#
# Sharpie - Sharpie King Size Permanent Marker, Color Assorted, Quantity 4, Tip Chisel
#
# Sharpie - Sharpie King Size Permanent Marker, Color Assorted, Quantity 4, Tip Chisel [ Officemax N215674PP ]
#
# Sharpie - Sharpie Retractable Permanent Marker, Color Assorted, Quantity 3, Style Retractable, Tip Fine
#
# Sharpie - Super Sharpie Permanent Marker, 4-Color Set - Black, Red, Blue, Green, Bold, Permanent, 4/Set
#
# Sharpie - Super Sharpie Permanent Marker, 4-Color Set - Black, Red, Blue, Green, Bold, Permanent, 4/Set [OfficeMax]
#
# Sharpie - Super Sharpie Permanent Marker, 4-Color Set, Color Black, Red, Blue, Green, Quantity 4/Set, Style Permanent, Tip Bold
#
# Sharpie - Super Sharpie Permanent Markers, Color Blue, Tip Bold
#
# Sharpie - Super Sharpie Permanent Markers, Color Blue, Tip Bold [ Officemax N233003 ]
#
# Sharpie - Super Sharpie Permanent Markers, Color Green, Tip Bold [ Officemax N233004 ]
#
# Sharpie - Super Sharpie Permanent Markers, Color Red, Tip Bold [ Officemax N233002 ]
#
# Sharpie - Super Twin-Tip Permanent Marker, 3-Color Set - Assorted, Fine/Chisel, Permanent, 3/Set
#
# Sharpie - Super Twin-Tip Permanent Marker, 3-Color Set, Color Assorted, Quantity 3/Set, Style Permanent, Tip Fine/Chisel
#
# Sharpie - Super Twin-Tip Permanent Marker, 3-Color Set, Color Assorted, Quantity 3/Set, Style Permanent, Tip Fine/Chisel [ Officemax N236404PP ]
#
# Sharpie - Super Twin-Tip Permanent Markers - Blue, Fine/Chisel [ OfficeMax ]
#
# Sharpie - Twin Tip Permanent Markers - 4-Color Set - Assorted: Black, Red, Blue, and Green, 4/Set, Twin Tip, Fine and Ultra Fine [ OfficeMax ]
#
# Sharpie - Twin Tip Permanent Markers - 4-Color Set, Color Assorted: Black, Red, Blue, and Green, Quantity 4/Set, Style Twin Tip, Tip Fine and Ultra Fine
#
# Sharpie - Twin Tip Permanent Markers - 4-Color Set, Color Assorted: Black, Red, Blue, and Green, Quantity 4/Set, Style Twin Tip, Tip Fine and Ultra Fine [ Officemax N232174PP ]
#
# Sharpie - Twin Tip Permanent Markers, Color Blue, Tip Fine/Ultra Fine [ Officemax N232003 ]
#
# Sharpie - Ultra Fine Permanent Markers, 12-Color Set - 12 Color Set: Black, Red, Blue, Green, Yellow, Orange, Brown, Purple, Turquoise, Berry, Lime, Aqua, 12/Set, Ultra Fine [ OfficeMax ]
#
# Sharpie - Ultra Fine Permanent Markers, 12-Color Set - 12 Color Set: Black, Red, Blue, Green, Yellow, Orange, Brown, Purple, Turquoise, Berry, Lime, Aqua, Ultra Fine, 12/Set
#
# Sharpie - Ultra Fine Permanent Markers, 12-Color Set, Color 12 Color Set: Black, Red, Blue, Green, Yellow, Orange, Brown, Purple, Turquoise, Berry, Lime, Aqua, Quantity 12/Set, Tip Ultra Fine
#
# Sharpie - Ultra Fine Permanent Markers, 12-Color Set, Color 12 Color Set: Black, Red, Blue, Green, Yellow, Orange, Brown, Purple, Turquoise, Berry, Lime, Aqua, Quantity 12/Set, Tip Ultra Finefficemax N237175PP ]
#
# Sharpie - Ultra Fine Permanent Markers, 24-Color Set, Color Assorted, Quantity 24/Set, Tip Ultra Fine
#
# Sharpie - Ultra Fine Permanent Markers, 24-Color Set, Color Assorted, Quantity 24/Set, Tip Ultra Fine [ Officemax N232893PP ]
#
# Sharpie - Ultra Fine Permanent Markers, 5-Color Set - 5-Color Set: 2 Black, 1 each of Red, Blue, Green, 5/Set, Extra Fine [ OfficeMax ]
#
# Sharpie - Ultra Fine Permanent Markers, 5-Color Set - 5-Color Set: 2 Black, 1 each of Red, Blue, Green, Extra Fine, 5/Set
#
# Sharpie - Ultra Fine Permanent Markers, 5-Color Set, Color 5-Color Set: 2 Black, 1 each of Red, Blue, Green, Quantity 5/Set, Tip Extra Fine
#
# Sharpie Accent - Liquid Pen-Style Highlighters, 10-Color Set, Color Assorted, Quantity 10/Set, Size Micro Chisel Tip [ Officemax N224415PP ]
#
# Sharpie Markers
#
# ===== Cluster 3=====
# MARKERS SHARPIE BLUE PK12 Sharpie Permanent Marker  Blue  Fine Tip  Leaves a permanent mark on any surface without smearing. Fine writing tip and quick drying ink guarantee clear  identifiabarkings. Supplied in pack of 12.
#
# MARKERS SHARPIE RED PK12Sharpie Permanent Marker, Red, Fine Tip
#
# MARKERS,SHARPIE RED PK12  [ SANFORD CORP / 30002 ] Sharpie Permanent Marker Red Fine Tip
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [ OfficeMax N230001 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [ OfficeMax N230001 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [ OfficeMax N230001 ] NEXT DAY
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [OfficeMax N230001] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [ OfficeMax N230003 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [ OfficeMax N230003 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [ OfficeMax N230003 ] NEXT DAY
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [OfficeMax N230003] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine [ OfficeMax N230002 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine [ OfficeMax N230002 ] IN STOCK
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine [ OfficeMax N230002 ] NEXT DAY
#
# Marker, Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine [OfficeMax N230002] IN STOCK
#
# Marker, Sharpie, Extra Fine, Blue [ OfficeMax N235003 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Blue [ OfficeMax N235003 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Blue [ OfficeMax N235003 ] NEXT DAY
#
# Marker, Sharpie, Extra Fine, Blue [OfficeMax N235003] IN STOCK
#
# Marker, Sharpie, Extra Fine, Red [ OfficeMax N235002 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Red [ OfficeMax N235002 ] IN STOCK
#
# Marker, Sharpie, Extra Fine, Red [ OfficeMax N235002 ] NEXT DAY
#
# Marker, Sharpie, Extra Fine, Red [OfficeMax N235002] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Blue [ OfficeMax N237003 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Blue [ OfficeMax N237003 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Blue [ OfficeMax N237003 ] NEXT DAY
#
# Marker, Sharpie, Ultra Fine, Blue [OfficeMax N237003] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Red [ OfficeMax N237002 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Red [ OfficeMax N237002 ] IN STOCK
#
# Marker, Sharpie, Ultra Fine, Red [ OfficeMax N237002 ] NEXT DAY
#
# Marker, Sharpie, Ultra Fine, Red [OfficeMax N237002] IN STOCK
#
# Marker; Sharpie; Blue Permanent Ink; Extra Fine Point; 1/EA
#
# Marker; Sharpie; Blue Permanent Ink; Extra Fine Point; 12/PK
#
# Pen; Sharpie; Permanent fine point; Black; 1/EA
#
# Pen; Sharpie; Permanent fine point; Black; 12/PK
#
# Red Ultra Fine Point Sharpie Permanent Marker,12/pack, tough,resilient tip produces a quick ink flow that dries fast,resists water and stays permanently,Work on glass,metal,photos,and plastic,Malmost anything with bright, lasting color.; 12/PK
#
# SHARPIE BLK PERM FINE
#
# SHARPIE BLK PERM FINE
#
# SHARPIE FINE RED 12 PACK
#
# SHARPIE RED X FINE
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers - Blue, Fine [OfficeMax]
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers - Green, Fine [OfficeMax]
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers - Red, Fine [OfficeMax]
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers, Color Blue, Tip Fine
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers, Color Green, Tip Fine
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers, Color Red, Tip Fine
#
# Sanford - Sharpie Retractable Fine Point Permanent Markers, Color Red, Tip Fine [ Officemax N232702 ]
#
# Sanford Sharpie Permanent Markers,Ultra Fine Point, Black,12/pack, tough, resilient tip produces a quick ink flow that dries fast,resists water and stays permanently,Work on glass,metal,photos,alastic; 12/PK
#
# Sharpie - Extra Fine Permanent Markers - Blue, 0.5mm
#
# Sharpie - Extra Fine Permanent Markers - Red, 0.5mm
#
# Sharpie - Extra Fine Permanent Markers, Color Blue, Tip 0.5mm
#
# Sharpie - Extra Fine Permanent Markers, Color Blue, Tip 0.5mm [ Officemax N235003 ]
#
# Sharpie - Extra Fine Permanent Markers, Color Red, Tip 0.5mm
#
# Sharpie - Extra Fine Permanent Markers, Color Red, Tip 0.5mm [ Officemax N235002 ]
#
# Sharpie - Fine Point Permanent Markers - Black, Fine
#
# Sharpie - Fine Point Permanent Markers - Black, Fine
#
# Sharpie - Fine Point Permanent Markers - Black, Fine [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers - Black, Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers - Blue, Fine
#
# Sharpie - Fine Point Permanent Markers - Blue, Fine
#
# Sharpie - Fine Point Permanent Markers - Blue, Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers - Green, Fine
#
# Sharpie - Fine Point Permanent Markers - Green, Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers - Red, Fine
#
# Sharpie - Fine Point Permanent Markers - Red, Fine
#
# Sharpie - Fine Point Permanent Markers - Red, Fine [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers - Red, Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, 12-Color Sets - Assorted, Fine Point, 12/Set [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, 12-Color Sets, Color Assorted, Quantity 12/Set, Tip Fine Point
#
# Sharpie - Fine Point Permanent Markers, 12-Color Sets, Color Assorted, Quantity 12/Set, Tip Fine Point [ Officemax N230075PP ]
#
# Sharpie - Fine Point Permanent Markers, 12-Color Sets, Color Assorted, Quantity 12/Set, Tip Fine Point [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, 24-Color Set - Assorted, 24/Set, Fine Point [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers, 24-Color Set, Color Assorted, Quantity 24/Set, Tip Fine Point
#
# Sharpie - Fine Point Permanent Markers, 24-Color Set, Color Assorted, Quantity 24/Set, Tip Fine Point [ Officemax N231993PP ]
#
# Sharpie - Fine Point Permanent Markers, 4-Color Set, Color Assorted, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, 4-Color Set, Color Assorted, Tip Fine [ Officemax N230074 ]
#
# Sharpie - Fine Point Permanent Markers, 5-Color Set - Assorted, 5/Set, Fine Point [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers, 5-Color Set - Assorted, Fine Point, 5/Set
#
# Sharpie - Fine Point Permanent Markers, 5-Color Set, Color Assorted, Quantity 5/Set, Tip Fine Point
#
# Sharpie - Fine Point Permanent Markers, 5-Color Set, Color Assorted, Quantity 5/Set, Tip Fine Point [ Officemax N230653PP ]
#
# Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [ Officemax N230001 ]
#
# Sharpie - Fine Point Permanent Markers, Color Black, Tip Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [ Officemax N230003 ]
#
# Sharpie - Fine Point Permanent Markers, Color Blue, Tip Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, Color Brown, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Brown, Tip Fine [ Officemax N230007 ]
#
# Sharpie - Fine Point Permanent Markers, Color Brown, Tip Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, Color Green, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Green, Tip Fine [ OfficeMax ]
#
# Sharpie - Fine Point Permanent Markers, Color Green, Tip Fine [ Officemax N230004 ]
#
# Sharpie - Fine Point Permanent Markers, Color Purple, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Purple, Tip Fine [OfficeMax]
#
# Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine
#
# Sharpie - Fine Point Permanent Markers, Color Red, Tip Fine [OfficeMax]
#
# Sharpie - Grip Pens, Ink Color Black, Point Fine, Quantity 3/Pack
#
# Sharpie - Grip Permanent Ink Pen - Blue, Fine
#
# Sharpie - Grip Permanent Ink Pen, Ink Color Assorted, Point Fine, Quantity 3/PK
#
# Sharpie - Grip Permanent Ink Pen, Ink Color Black, Point Fine
#
# Sharpie - Grip Permanent Ink Pen, Ink Color Red, Point Fine
#
# Sharpie - Grip Retractable Pens - Assorted, Fine, 3/PK [ OfficeMax ]
#
# Sharpie - Grip Retractable Pens, Ink Color Assorted, Point Fine, Quantity 3/PK
#
# Sharpie - Grip Retractable Pens, Ink Color Assorted: green, purple and orange, Point Fine, Quantity 3/PK
#
# Sharpie - Grip Retractable Pens, Ink Color Black, Point Fine
#
# Sharpie - Metallic Permanent Marker - Silver, Fine, Permanent, 4/Pack
#
# Sharpie - Metallic Permanent Marker, 4-Marker Pack - Silver, Fine, Permanent, 4/Pack [OfficeMax]
#
# Sharpie - Permanent Ink Pen - Blue, 12 Pack, Color Blue, Point Fine, Quantity 12
#
# Sharpie - Permanent Ink Pen - Red, 12 Pack, Color Red, Point Fine, Quantity 12
#
# Sharpie - Permanent Ink Pen, Ink Color Assorted, 6/pk, Point Fine
#
# Sharpie - Permanent Ink Pen, Ink Color Blue, Point Medium
#
# Sharpie - Permanent Ink Pen, Ink Color Red, Point Medium
#
# Sharpie - Permanent Retractable Pen, Ink Color Black, Point Fine
#
# Sharpie - Permanent Retractable Pen, Ink Color Blue, Point Fine
#
# Sharpie - Permanent Retractable Pen, Ink Color Red, Point Fine
#
# Sharpie - Refill for Stainless Steel Fine Point permanent Marker - Black, Fine
#
# Sharpie - Refill for Stainless Steel Fine Point permanent Marker, Color Black, Tip Fine
#
# Sharpie - Retractable Fine Point Permanent Markers, 12-Color Set, Color Includes black, red, blue, green, orange, turquoise, berry, lime, purple, aqua, plum and navy, Quantity 12/Set, Styetractable, Tip Fine
#
# Sharpie - Retractable Fine Point Permanent Markers, 8-Color Set - Includes black, red, blue, green, orange, turquoise, berry and lime, 8/Set, Fine [ OfficeMax ]
#
# Sharpie - Retractable Fine Point Permanent Markers, 8-Color Set - Includes black, red, blue, green, orange, turquoise, berry and lime, Fine, 8/Set
#
# Sharpie - Retractable Fine Point Permanent Markers, 8-Color Set, Color Includes black, red, blue, green, orange, turquoise, berry and lime, Quantity 8/Set, Tip Fine
#
# Sharpie - Retractable Ultra Fine Tip Permanent Marker - Blue, Ultra Fine, Standard, 1
#
# Sharpie - Sharpie Fine Tip Permanent Marker, Color Assorted, Tip Fine Point
#
# Sharpie - Sharpie Retractable Fine Point Permanent Markers - Red, Fine
#
# Sharpie - Stainless Steel Fine Point Permanent Marker - Black, Fine
#
# Sharpie - Twin Tip Permanent Markers, Color Red, Tip Fine/Ultra Fine [ Officemax N232002 ]
#
# Sharpie - Twin-Tip Permanent Markers, Color Blue, Tip Fine/Ultra Fine
#
# Sharpie - Twin-Tip Permanent Markers, Color Red, Tip Fine/Ultra Fine
#
# Sharpie - Ultra Fine Permanent Markers - Blue, 0.3mm [OfficeMax]
#
# Sharpie - Ultra Fine Permanent Markers - Green, 0.3mm [OfficeMax]
#
# Sharpie - Ultra Fine Permanent Markers - Red, 0.3mm [OfficeMax]
#
# Sharpie - Ultra Fine Permanent Markers, 4-Color Set, Color 4-Color, Tip Ultra Fine
#
# Sharpie - Ultra Fine Permanent Markers, 4-Color Set, Color 4-Color, Tip Ultra Fine [OfficeMax]
#
# Sharpie - Ultra Fine Permanent Markers, Color Blue, Tip 0.3mm [ Officemax N237003 ]
#
# Sharpie - Ultra Fine Permanent Markers, Color Green, Tip 0.5mm [ Officemax N235004 ]
#
# Sharpie - Ultra Fine Point Permanent Markers - Black, 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers - Black, 0.3mm [ OfficeMax ]
#
# Sharpie - Ultra Fine Point Permanent Markers - Black, Ultra Fine
#
# Sharpie - Ultra Fine Point Permanent Markers - Blue, 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers - Blue, 0.3mm [ OfficeMax ]
#
# Sharpie - Ultra Fine Point Permanent Markers - Blue, Ultra Fine
#
# Sharpie - Ultra Fine Point Permanent Markers - Red, 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers - Red, 0.3mm [ OfficeMax ]
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Black, Tip 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Black, Tip 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Blue, Tip 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Green, Tip 0.3mm
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Green, Tip 0.5mm
#
# Sharpie - Ultra Fine Point Permanent Markers, Color Red, Tip 0.3mm
#
# Sharpie Extra Fine Point Permanent Marker, Black, 12/PK, quick drying, water resistant ink good for use where precision marking is needed. Permanent on most surfaces-metal, glass, plastic, foilubber, waxed paper, film, circuit boards.; 1/PK
#
# Sharpie Extra Fine Point Permanent Marker, Black, 12/PK, quick drying, water resistant ink good for use where precision marking is needed. Permanent on most surfaces-metal, glass, plastic, foilubber, waxed paper, film, circuit boards.; 1/PK; 1/PK
#
# Sharpie Permanent Marker, Blue, Fine Tip, Leaves a permanent mark on any surface without smearing. Fine writing tip and quick drying ink guarantee clear, identifiable markings. Supplied in pack 2.; 1/PK; 1/PK
#
# Sharpie Permanent Marker, Red, Fine Tip, Leaves a permanent mark on any surface without smearing. Fine writing tip and quick drying ink guarantee clear, identifiable markings. Supplied in pack 2.; 1/PK; 1/PK
#
# Sharpie Unltra fine
#
# Sharpies Ultra Fine
#
# Ultra Fine Sharpie, Blue
#
# ===== Cluster 0=====
# Sanford(R) Sharpie Accent(R) Highlighter, Fluorescent Green [ Office Depot ]
#
# Sanford(R) Sharpie Accent(R) Highlighter, Pink [ Office Depot ]
#
# Sanford(R) Sharpie Accent(R) Highlighter, Turquoise Blue [ Office Depot ]
#
# Sanford(R) Sharpie Accent(R) Retractable Highlighters, Fluorescent Yellow, Pack Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Accent(R) Mini Highlighter, Fluorescent Yellow [ Office Depot ]
#
# Sanford(R) Sharpie(R) Chisel Tip Permanent Markers, Assorted Colors, Pack Of 4 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Chisel Tip Permanent Markers, Assorted Colors, Pack Of 8 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Chisel Tip Permanent Markers, Black, Pack Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Assorted Colors, Pack Of 4 [ Office Depot 183046 ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Assorted Colors, Pack Of 4 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Black, Box Of 12 [ Office Depot 447201 ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Black, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Blue, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Red, Box Of 12 [ Office Depot 447334 ]
#
# Sanford(R) Sharpie(R) Extra-Fine Point Permanent Markers, Red, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Flip Chart(TM) Markers, Set Of 8 Colors [ Office Depot ]
#
# Sanford(R) Sharpie(R) Grip Permanent Markers, Black, Pack Of 12 [Office Depot]
#
# Sanford(R) Sharpie(R) Industrial Permanent Markers, Extra-Fine Point, Black, Pack Of 12 [ Office Depot 258391 ]
#
# Sanford(R) Sharpie(R) Industrial Permanent Markers, Extra-Fine Point, Black, Pack Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Industrial Permanent Markers, Fine Point, Black, Pack Of 12 [ Office Depot 258381 ]
#
# Sanford(R) Sharpie(R) Industrial Permanent Markers, Fine Point, Black, Pack Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Industrial Permanent Markers, Fine Point, Black, Pack Of 12 [Office Depot]
#
# Sanford(R) Sharpie(R) King Size(TM) Permanent Markers, Black, Pack Of 12 [ Office Depot 202812 ]
#
# Sanford(R) Sharpie(R) King Size(TM) Permanent Markers, Black, Pack Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Magnum(R) Permanent Marker, Black [ Office Depot ]
#
# Sanford(R) Sharpie(R) Metallic Markers, Silver, Pack Of 4 [ Office Depot 592264 ]
#
# Sanford(R) Sharpie(R) Metallic Markers, Silver, Pack Of 4 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Mini Fine-Point Permanent Markers, Assorted Colors, Pack Of 12 [ Office Depot 138928 ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Assorted Colors, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Assorted Colors, Pack of 8 [Office Depot]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Black, Pack of 12 [ Office Depot 203349 ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Black, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Black, Pack of 12 [Office Depot]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Blue, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Red, Pack of 12 [ Office Depot 203356 ]
#
# Sanford(R) Sharpie(R) Permanent Fine-Point Markers, Red, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 12 [ Office Depot 270776 ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 24 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 5 [ Office Depot 621516 ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Assorted Colors, Pack of 5 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Black, Pack of 12 [ Office Depot 451898 ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Black, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Black, Pack of 12 [Office Depot]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Blue, Pack of 12 [ Office Depot 451880 ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Blue, Pack of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Permanent Ultra-Fine Point Markers, Red, Pack of 12 [ Office Depot 451872 ]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Fluorescent Orange, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Fluorescent Yellow, Box Of 12 [ Office Depot 619627 ]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Fluorescent Yellow, Box Of 12 [Office Depot]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Pink, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Turquoise, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Pocket Accent(R) Highlighters, Yellow, Box Of 12 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Professional Permanent Marker, Chisel Tip, Black [ Office Depot ]
#
# Sanford(R) Sharpie(R) Professional Permanent Marker, Chisel Tip, Blue [ Office Depot 162694 ]
#
# Sanford(R) Sharpie(R) RT Retractable Permanent Markers, Fine Point, Assorted Ink Colors, Pack Of 3 [ Office Depot ]
#
# Sanford(R) Sharpie(R) RT Retractable Permanent Markers, Ultra Fine Point, Red Ink, Pack Of 12 [ Office Depot 563630 ]
#
# Sanford(R) Sharpie(R) Twin-Tip CD/DVD Permanent Markers, Assorted Colors, Pack of 4 [ Office Depot 258424 ]
#
# Sanford(R) Sharpie(R) Twin-Tip CD/DVD Permanent Markers, Black, Pack of 4 [ Office Depot ]
#
# Sanford(R) Sharpie(R) Twin-Tip Permanent Marker, Red [ Office Depot ]
#
# Sanford(R) Super Sharpie(R) Fine-Tip Permanent Markers, Black, Pack Of 6 [ Office Depot 142364 ]
#
# Sanford(R) Super Sharpie(R) Fine-Tip Permanent Markers, Black, Pack Of 6 [ Office Depot ]
#
# Sharpie(R) Fine Point Pens, 0.3mm, Assorted, Pack Of 4 [ Office Depot ]
#
# Sharpie(R) Fine Point Pens, 0.3mm, Black, Pack Of 12 [ Office Depot 701025 ]
#
# Sharpie(R) Industrial Permanent Marker, Extra-Fine Point, Black [ Office Depot ]
#
# Sharpie(R) Industrial Permanent Marker, Fine Point, Black [ Office Depot ]
#
# Sharpie(R) King Size(TM) Permanent Markers, Assorted Colors, Pack Of 4 [ Office Depot 621524 ]
#
# Sharpie(R) Pocket Accent(R) Highlighter, Yellow [ Office Depot ]
#
# Sharpie(R) RT Retractable Permanent Markers, Ultra-Fine Point, Assorted, Pack Of 8 [ Office Depot 355835 ]
#
# Sharpie(R) Twin-Tip Permanent Markers, Assorted Fashion Colors, Pack Of 8 [ Office Depot ]
#
# Sharpie(R) Twin-Tip Permanent Markers, Assorted Fashion Colors, Pack Of 8 [ Office Depot ]

# %%
# From the printout above, Cluster 4 seems to contain mostly "Black" color items, but other clusters just have
# colors all over the place. This unsupervised algorithm seems hard to control/tweak.

# TO-DO: 
# Plot the vectorized texts transformed via tf-idf and denote the cluster using colors.
# Probably matplotlib or some sort of plotting libraries/tools

# TO-DO:
# Try other methods for feature extraction, texts vectorization, and clustering

# %% [markdown]
# # gensim
# Following tutorial:
# https://radimrehurek.com/gensim/tutorial.html

# %%
# enable logging on the terminal during training, etc
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import gensim
# need to install this on my machine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-12a099f4c7d9> in <module>()
# ----> 1 import gensim
#       2 # need to install this on my machine
#
# ModuleNotFoundError: No module named 'gensim'
